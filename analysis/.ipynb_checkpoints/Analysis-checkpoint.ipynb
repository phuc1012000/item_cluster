# %%
# !date
# Out:
# Thứ hai, 09 Tháng 12 năm 2019 18:08:11 +07

# %% [markdown]
# + Recive Client Requirement
# + Create Requirement.ipynb

# %%
# !date
# Out:
# Thứ hai, 09 Tháng 12 năm 2019 18:22:36 +07

# %% [markdown]
# ### Analyze Client Data
#
# Pre-Process:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# both data_set are small memory size, and don't have any null value.
#
# __purchase history__:
# + it 's strange that user_id can appear multiple times
# ![image.png](attachment:image.png)
# + Id are stored in __string__ so it need to be engineer into list of integer

# %% [markdown]
# __item_to_id__:
# + 2 columns doesn't have any duplicate value
# + The items are general items that could be seen in any grocery store:
#         + bread, drink, fresh ingredients, soap, fruid.
#         + two things feel like out of place: baby items and pet items. Although it makes sense that we could find these items in grocery store but it feels too vague and less likely to relate to other items

# %%
# !date
# Out:
# Thứ hai, 09 Tháng 12 năm 2019 19:46:03 +07

# %% [markdown]
# After engineer the id in purchase history, there are some item_id duplicate with the same user_id in different row
#
# ![image.png](attachment:image.png)

# %%
# !date
# Out:
# Thứ hai, 09 Tháng 12 năm 2019 23:36:53 +07

# %% [markdown]
# ### User_id: 13705 that has the buy the most kinds of items: 41 in 6 times
# + unique_user have been save as '/home/phuc/Desktop/Work/Data Sience/Project/Cluster Item selling/generated/unique_user.pkl'
# + On Average, 1 customer come to store and buy 7 items each times they visit the store

# %%
# !date
# Out:
# Thứ ba, 10 Tháng 12 năm 2019 00:10:28 +07

# %% [markdown]
# Saved Engineer purchase_history.pkl

# %%
# !date
# Out:
# Thứ ba, 10 Tháng 12 năm 2019 06:51:44 +07

# %% [markdown]
# + Saved file
#
#         '/home/phuc/Desktop/Work/Data Sience/Project/Cluster Item selling/generated/item_to_id.pkl'
#     that contains the list of user_id that buy item the most time

# %%
# !date
# Out:
# Thứ ba, 10 Tháng 12 năm 2019 07:44:10 +07

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# + save feature data contain frequency of item_id come together
# + In the graph above, we are sure that we could cluster the item

# %%
# !date
# Out:
# Thứ tư, 11 Tháng 12 năm 2019 20:18:13 +07
